# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Using cached feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting sgmllib3k (from feedparser)
#   Using cached sgmllib3k-1.0.0-py3-none-any.whl
# Using cached feedparser-6.0.11-py3-none-any.whl (81 kB)
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.11 sgmllib3k-1.0.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import feedparser
from datetime import datetime

rss_feeds = [
    'http://rss.cnn.com/rss/cnn_topstories.rss',
    'http://qz.com/feed',
    'http://feeds.foxnews.com/foxnews/politics',
    'http://feeds.reuters.com/reuters/businessNews',
    'http://feeds.feedburner.com/NewshourWorld',
    'https://feeds.bbci.co.uk/news/world/asia/india/rss.xml'
]

# %%
import torch
from transformers import DistilBertTokenizer, DistilBertModel

# Check for GPU availability and set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the DistilBERT model and tokenizer
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
model = DistilBertModel.from_pretrained("distilbert-base-uncased").to(device)

# Define a padding token if it doesn't exist
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token  # Set the padding token to the end-of-sequence token

# Example articles
# articles = [
#     {
#         "title": "Protests Erupt in the Capital",
#         "description": "Citizens are rallying against new legislation."
#     },
#     {
#         "title": "Hurricane Causes Widespread Damage",
#         "description": "The hurricane has left thousands homeless."
#     },
#     {
#         "title": "A New Vaccine Offers Hope",
#         "description": "Scientists have developed a vaccine that is 90% effective."
#     },
#     {
#         "title": "Earthquake Rocks the City",
#         "description": "A major earthquake has struck, causing extensive damage."
#     }
# ]

# Define categories
categories = [
    "Terrorism / protest / political unrest / riot",
    "Positive / Uplifting",
    "Natural Disasters"
]

# Function to generate embeddings
def get_embeddings(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True).to(device)  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(**inputs)
        embeddings = outputs.last_hidden_state.mean(dim=1)  # Average pooling over the last hidden state
    return embeddings

# Generate embeddings for categories
category_embeddings = [get_embeddings(category) for category in categories]

# Function to classify articles
def classify_article(article):
    full_text = f"{article['title']}: {article['description']}"
    article_embedding = get_embeddings(full_text)

    # Calculate cosine similarity
    similarities = []
    for category_embedding in category_embeddings:
        sim = torch.nn.functional.cosine_similarity(article_embedding, category_embedding)
        similarities.append(sim.item())
    
    # Get the category with the highest similarity
    max_index = similarities.index(max(similarities))
    max_sim = max(similarities)
    if max_sim>0.6:
        return categories[max_index],max_sim
    else :
        return "Others",max_sim

# %%
def parse_feed(url):
    feed = feedparser.parse(url)
    articles = []
    for entry in feed.entries:
        # Extract the media content (if available)
        media_content = None
        if 'media_content' in entry:
            media_content = entry.media_content[0]['url'] if entry.media_content else None
        
        # Extract published date
        published_date = None
        if hasattr(entry, 'published_parsed'):
            published_date = datetime(*entry.published_parsed[:6])
        
        article = {
            'title': entry.title,
            'content': entry.summary if 'summary' in entry else '',  # Handle missing summary
            'published': published_date,
            'url': entry.link,
            'media_url': media_content  # Add media URL if present
        }
        articles.append(article)
    return articles

# Parse all feeds
for feed_url in rss_feeds:
    articles = parse_feed(feed_url)
    # Add logic to process/store articles
    for article in articles:
        print(article)
# Out:
# {'title': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced', 'content': '', 'published': datetime.datetime(2023, 4, 19, 12, 44, 51), 'url': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418164538-02-dominion-fox-trial-settlement-0418-super-169.jpg'}
# {'title': 'Dominion still has pending lawsuits against election deniers such as Rudy Giuliani and Sidney Powell', 'content': '', 'published': None, 'url': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/h_8d51e3ae2714edaa0dace837305d03b8', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417170417-fox-news-headquarters-0228-super-169.jpg'}
# {'title': 'Here are the 20 specific Fox broadcasts and tweets Dominion says were defamatory', 'content': "• Fox-Dominion trial delay 'is not unusual,' judge says\n• Fox News' defamation battle isn't stopping Trump's election lies", 'published': datetime.datetime(2023, 4, 17, 16, 1, 11), 'url': 'https://www.cnn.com/2023/04/17/media/dominion-fox-news-allegations/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230416140110-maria-bartiromo-file-020823-restricted-super-169.jpg'}
# {'title': "Judge in Fox News-Dominion defamation trial: 'The parties have resolved their case'", 'content': 'The judge just announced in court that a settlement has been reached in the historic defamation case between Fox News and Dominion Voting Systems.', 'published': datetime.datetime(2023, 4, 19, 8, 28, 17), 'url': 'https://www.cnn.com/2023/04/18/media/fox-dominion-settlement/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418112020-02-delaware-fox-dominion-trial-court-exterior-0418-super-169.jpg'}
# {'title': "'Difficult to say with a straight face': Tapper reacts to Fox News' statement on settlement", 'content': "A settlement has been reached in Dominion Voting Systems' defamation case against Fox News, the judge for the case announced. The network will pay more than $787 million to Dominion, a lawyer for the company said.", 'published': datetime.datetime(2023, 4, 18, 21, 17, 44), 'url': 'https://www.cnn.com/videos/politics/2023/04/18/jake-tapper-dominion-lawsuit-settlement-fox-news-statement-lead-vpx.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418164748-tapper-smile-vpx-super-169.jpg'}
# {'title': 'Millions in the US could face massive consequences unless McCarthy can navigate out of a debt trap he set for Biden', 'content': '• DeSantis goes to Washington, a place he once despised, looking for support to take on Trump\n• Opinion: For the GOP to win, it must ditch Trump\n• Chris Christie mulling 2024 White House bid\n• Analysis: The fire next time has begun burning in Tennessee', 'published': datetime.datetime(2023, 4, 18, 20, 34, 45), 'url': 'https://www.cnn.com/2023/04/18/politics/mccarthy-biden-debt-ceiling/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417222359-mccarthy-biden-debt-ceiling-042023-super-169.jpg'}
# {'title': 'White homeowner accused of shooting a Black teen who rang his doorbell turns himself in to face criminal charges', 'content': "• 'A major part of Ralph died': Aunt of teen shot after ringing wrong doorbell speaks\n• 20-year-old woman shot after friend turned into the wrong driveway in upstate New York, officials say", 'published': datetime.datetime(2023, 4, 19, 4, 29, 5), 'url': 'https://www.cnn.com/2023/04/18/us/kansas-city-ralph-yarl-shooting-tuesday/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417181520-03b-ralph-yarl-cropped-super-169.jpg'}
# {'title': "Newly released video shows scene of Jeremy Renner's snowplow accident", 'content': 'Newly released body camera footage shows firefighters and sheriff\'s deputies rushing to help actor Jeremy Renner after a near-fatal snowplow accident in January. The "Avengers" actor broke more than 30 bones and suffered other severe injuries. CNN\'s Chloe Melas has more.', 'published': datetime.datetime(2023, 4, 18, 14, 9, 43), 'url': 'https://www.cnn.com/videos/us/2023/04/18/jeremy-renner-snowplow-accident-bodycam-nc-melas-contd-vpx.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418093916-jeremy-renner-snowplow-body-cam-super-169.jpg'}
# {'title': 'Jake Gyllenhaal and Jamie Lee Curtis spent the Covid-19 lockdown together', 'content': "It's sourdough bread and handstands for Jake Gyllenhaal and Jamie Lee Curtis.", 'published': datetime.datetime(2023, 4, 18, 14, 40, 32), 'url': 'https://www.cnn.com/2023/04/18/entertainment/jake-gyllenhaal-jamie-lee-curtis-pandemic-living/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418143926-jake-gyllenhaal-jamie-lee-curtis-041723-super-169.jpeg'}
# {'title': 'Toddler crawls through White House fence, prompts Secret Service response', 'content': 'A tiny intruder infiltrated White House grounds Tuesday, prompting a swift response from the US Secret Service.', 'published': datetime.datetime(2023, 4, 18, 17, 38, 16), 'url': 'https://www.cnn.com/2023/04/18/politics/white-house-toddler/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418130032-01-white-house-toddler-super-169.jpg'}
# {'title': "Jamie Foxx remains hospitalized nearly a week after 'medical complication'", 'content': 'Jamie Foxx remains hospitalized in Georgia nearly a week after his daughter revealed the actor experienced a "medical complication," a source with knowledge of the matter told CNN on Monday.', 'published': datetime.datetime(2023, 4, 18, 0, 27, 7), 'url': 'https://www.cnn.com/2023/04/17/entertainment/jamie-foxx-remains-hospitalized/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417195159-jamie-foxx-health-update-042023-super-169.jpg'}
# {'title': "A 13-year-old dies after participating in a Benadryl TikTok 'challenge'", 'content': 'A 13-year-old in Ohio has died after "he took a bunch of Benadryl," trying a dangerous TikTok challenge that\'s circulating online, according to a CNN affiliate and a GoFundMe account from his family.', 'published': datetime.datetime(2023, 4, 19, 15, 1, 6), 'url': 'https://www.cnn.com/2023/04/18/us/benadryl-tiktok-challenge-teen-death-wellness/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418141115-jacob-stevens-gofundme-super-169.jpg'}
# {'title': 'See pizza delivery guy take out suspect fleeing police', 'content': "Pizza guy delivers more than a pie, taking out a fleeing suspect. CNN's Jeanne Moos shows him putting his best foot forward.", 'published': datetime.datetime(2023, 4, 18, 16, 40, 22), 'url': 'https://www.cnn.com/videos/us/2023/04/18/pizza-guy-trips-perp-moos-cprog-orig-bdk.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418122318-pizza-delivery-guy-trips-perp-split-super-169.jpg'}
# {'title': 'Netflix is winding down its DVD business after 25 years', 'content': 'Netflix is officially winding down the business that helped make it a household name.', 'published': datetime.datetime(2023, 4, 18, 20, 10, 51), 'url': 'https://www.cnn.com/2023/04/18/media/netflix-dvd-red-envelopes/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418155502-netflix-dvd-envelope-super-169.jpg'}
# {'title': "FTC chair Lina Khan warns AI could 'turbocharge' fraud and scams", 'content': 'Artificial intelligence tools such as ChatGPT could lead to a "turbocharging" of consumer harms including fraud and scams, and the US government has substantial authority to crack down on AI-driven consumer harms under existing law, members of the Federal Trade Commission said Tuesday.', 'published': datetime.datetime(2023, 4, 18, 17, 59, 38), 'url': 'https://www.cnn.com/2023/04/18/tech/lina-khan-ai-warning/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418125823-02-internet-user-stock-super-169.jpg'}
# {'title': 'Eating too much of these foods is driving the rise in type 2 diabetes, study says', 'content': 'Gobbling up too many refined wheat and rice products, along with eating too few whole grains, is fueling the growth of new cases of type 2 diabetes worldwide, according to a new study that models data through 2018.', 'published': datetime.datetime(2023, 4, 17, 16, 2, 46), 'url': 'https://www.cnn.com/2023/04/17/health/rise-type-2-diabetes-global-wellness/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417103845-bacon-sausage-potatoes-eggs-restricted-super-169.jpg'}
# {'title': "ADHD medication abuse in schools is a 'wake-up call'", 'content': "At some middle and high schools in the United States, 1 in 4 teens report they've abused prescription stimulants for attention deficit hyperactivity disorder during the year prior, a new study found.", 'published': datetime.datetime(2023, 4, 25, 17, 44, 36), 'url': 'https://www.cnn.com/2023/04/18/health/teen-misuse-adhd-meds-wellness/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418082957-teen-misuse-adhd-meds-wellness-stock-super-169.jpg'}
# {'title': 'Apple CEO was presented with an original Macintosh. See his reaction', 'content': "CEO Tim Cook personally welcomed customers to the new Apple store in Mumbai as the tech company opens its first retail stores in India. CNN's Vedika Sud reports.", 'published': datetime.datetime(2023, 4, 18, 9, 17, 25), 'url': 'https://www.cnn.com/videos/tech/2023/04/18/apple-store-mumbai-india-ceo-tim-cook-vedika-sud-ovn-biz-ldn-vpx.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418095406-apple-india-tim-cook-super-169.jpg'}
# {'title': 'Democrats bash Justice Clarence Thomas but their plan to investigate ethics allegations is unclear', 'content': 'Senate Democrats railed against Justice Clarence Thomas on Tuesday amid reports that the Supreme Court conservative failed to disclose luxury travel, gifts and a real estate transaction involving a GOP megadonor, but their plan to investigate the conservative jurist remains unclear.', 'published': datetime.datetime(2023, 4, 18, 20, 29, 46), 'url': 'https://www.cnn.com/2023/04/18/politics/clarence-thomas-ethics-democrats/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417104735-01-clarence-thomas-2016-file-super-169.jpg'}
# {'title': "Russia is 'going backwards' in equipment and deploying post WWII-era tanks, according to Western officials", 'content': '• Jailed Wall Street Journal reporter Evan Gershkovich denied detention appeal in Moscow\n• Putin visits Russian troops at military headquarters in Kherson\n• Watch moment WSJ journalist appears in Russian court', 'published': None, 'url': 'https://www.cnn.com/europe/live-news/russia-ukraine-war-news-04-18-23/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417210750-wagner-commanders-041723-super-169.jpg'}
# {'title': 'Two Russians claiming to be former Wagner commanders admit killing children and civilians in Ukraine', 'content': 'Two Russian men who claim to be former Wagner Group commanders have told a human rights activist that they killed children and civilians during their time in Ukraine.', 'published': datetime.datetime(2023, 4, 18, 19, 7, 52), 'url': 'https://www.cnn.com/2023/04/17/europe/wagner-commanders-russia-kill-children-intl-hnk/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417210750-wagner-commanders-041723-super-169.jpg'}
# {'title': "'My stomach is hurting from laughing': Hear panelist's reaction to DeSantis' threat to Disney", 'content': 'CNN panelists react to Florida Gov. Ron DeSantis floating the idea of building a competing theme park next to Disney World in Orlando.', 'published': datetime.datetime(2023, 4, 18, 3, 24, 56), 'url': 'https://www.cnn.com/videos/business/2023/04/18/desantis-disney-competition-panel-reax-pt-vpx.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417224705-desantis-panel-vpx-super-169.jpg'}
# {'title': 'GOP prepared to block vote to replace Feinstein on Senate Judiciary', 'content': 'Senate Majority Leader Chuck Schumer said on Tuesday that he hopes to replace Democratic Sen. Dianne Feinstein on the Senate Judiciary Committee with Sen. Ben Cardin of Maryland and aims to set up a floor vote on the issue this afternoon, which Republicans are expected to block.', 'published': datetime.datetime(2023, 4, 18, 22, 3, 13), 'url': 'https://www.cnn.com/2023/04/18/politics/schumer-senate-feinstein-vote-cardin/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230214135512-01-dianne-feinstein-0213-super-169.jpg'}
# {'title': 'Oklahoma governor calls on officials to resign over recording of racist and threatening remarks', 'content': '', 'published': datetime.datetime(2023, 4, 18, 17, 33, 17), 'url': 'https://www.cnn.com/2023/04/18/us/mccurtain-county-oklahoma-officials-recording/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/150325082152-social-gfx-cnn-logo-super-169.jpg'}
# {'title': 'McCarthy slams Biden in handling of US debt', 'content': 'House Speaker Kevin McCarthy traveled to Wall Street on Monday to deliver a fresh warning that the House GOP majority will refuse to lift a cap on government borrowing unless Biden agrees to spending cuts that would effectively neutralize his domestic agenda.', 'published': datetime.datetime(2023, 4, 18, 22, 3, 1), 'url': 'https://www.cnn.com/videos/politics/2023/04/18/kevin-mccarthy-wall-street-speech-debt-ceiling-biden-economy-vpx.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418162757-mccarthy-biden-super-169.jpg'}
# {'title': 'US warns Russia not to touch American nuclear technology at Ukrainian nuclear plant', 'content': "The US has sensitive nuclear technology at a nuclear power plant inside Ukraine and is warning Russia not to touch it, according to a letter the US Department of Energy sent to Russia's state-owned nuclear energy firm Rosatom last month.", 'published': datetime.datetime(2023, 4, 19, 8, 35, 33), 'url': 'https://www.cnn.com/2023/04/18/politics/us-warns-russia-zaporizhzhia-nuclear-plant/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230303094926-zaporizhzhia-nuclear-plant-file-101422-super-169.jpg'}
# {'title': 'Repeated gunshots fired on live TV as ex-lawmaker shot by assassins', 'content': "Atiq Ahmed, a former lawmaker in India's parliament, convicted of kidnapping, was shot dead along with his brother while police were escorting them for a medical check-up in a slaying caught on live television on Saturday. CNN's Vedika Sud reports.", 'published': datetime.datetime(2023, 4, 18, 9, 41, 42), 'url': 'https://www.cnn.com/videos/world/2023/04/18/india-ex-lawmaker-atiq-ahmed-assassination-sud-pkg-contd-ovn-intl-hnk-vpx.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418132241-screengrab-indian-lawmaker-super-169.jpg'}
# {'title': 'FDA clears the way for additional bivalent boosters for certain vulnerable individuals', 'content': "The U.S. Food and Drug Administration amended the terms of its emergency use authorizations for the Pfizer and Moderna bivalent vaccines on Tuesday, allowing people ages 65 and older and certain people with weakened immunity to get additional doses before this fall's vaccination campaigns.", 'published': datetime.datetime(2023, 4, 18, 15, 9, 15), 'url': 'https://www.cnn.com/2023/04/18/health/fda-bivalent-booster-additional-doses/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418103631-covid-vaccine-booster-bivalent-super-169.jpg'}
# {'title': 'Maine authorities detained a person of interest after 4 people were found dead in a home and 3 others shot while driving', 'content': 'Maine authorities have detained a person of interest and continue to investigate after two shooting incidents that appear to be connected left at least four people dead and three others injured, state police said.', 'published': datetime.datetime(2023, 4, 19, 1, 49, 51), 'url': 'https://www.cnn.com/2023/04/18/us/maine-shooting-bowdoin-yarmouth/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418144820-01-yarmouth-shooting-0418-super-169.jpg'}
# {'title': "Southwest says flights resumed after delays caused by 'tech issues'", 'content': '• Delta Air Lines reports record bookings for summer travel\n• Air France and Airbus acquitted in trial over 2009 plane crash', 'published': datetime.datetime(2023, 4, 18, 17, 15, 29), 'url': 'https://www.cnn.com/travel/article/southwest-airlines-flight-delays/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230323105146-southwest-airlines-file-101121-super-169.jpeg'}
# {'title': 'Damar Hamlin cleared to resume football activities after January cardiac arrest', 'content': 'Buffalo Bills safety Damar Hamlin, who has been cleared to resume football activities, said Tuesday his cardiac arrest during an NFL game in January was caused by commotio cordis.', 'published': datetime.datetime(2023, 4, 18, 22, 11, 37), 'url': 'https://www.cnn.com/2023/04/18/sport/damar-hamlin-cleared-to-train-nfl-spt-intl/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418173748-damar-hamlin-super-169.jpg'}
# {'title': 'Pilot makes history after landing on top of a 56-story hotel', 'content': 'Polish pilot Lukasz Czepiela made history after landing a plane on a helipad at the top of a 56-story hotel in Dubai.', 'published': datetime.datetime(2023, 3, 19, 11, 22, 30), 'url': 'https://www.cnn.com/videos/travel/2023/03/17/pilot-lands-on-dubai-helipad-cprog-orig-aw-ao.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230317140252-helipad-plane-landing-super-169.jpg'}
# {'title': 'Top US Navy admiral defends non-binary sailor amid some Republican criticism', 'content': 'The top US Navy admiral ardently defended a non-binary sailor on Tuesday amid some criticism from Republican lawmakers, saying he is "particularly proud of this sailor."', 'published': datetime.datetime(2023, 4, 18, 19, 56, 40), 'url': 'https://www.cnn.com/2023/04/18/politics/gilday-defends-non-binary-sailor/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/210615165026-michael-gilday-file-super-169.jpg'}
# {'title': 'Fulton County DA says fake Trump electors are incriminating one another and wants lawyer disqualified', 'content': "The Fulton County District Attorney's office said some fake electors for Donald Trump have implicated each other in potential criminal activity and is seeking to disqualify their lawyer, according to a new court filing.", 'published': datetime.datetime(2023, 4, 19, 15, 31, 24), 'url': 'https://www.cnn.com/2023/04/18/politics/fulton-county-trump-fake-electors/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230109112258-trump-willis-split-super-169.jpg'}
# {'title': 'High speed trains are racing across the world. But not in America', 'content': 'High speed trains have proved their worth across the world over the past 50 years.', 'published': datetime.datetime(2023, 4, 19, 2, 39, 40), 'url': 'https://www.cnn.com/travel/article/high-speed-rail-us/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417085801-04-high-speed-rail-china-restricted-super-169.jpg'}
# {'title': 'Podcast: One country musician is calling for other artists to oppose assault rifles', 'content': '', 'published': None, 'url': 'https://www.cnn.com/audio/podcasts/the-assignment/episodes/42a2f0e2-066a-4675-82ff-afe2016a0bb5', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/221117142556-the-assignment-with-audie-cornish-super-169.jpg'}
# {'title': "Here's what you need to know if you haven't filed your return yet — and even if you have", 'content': "It's April 18, the official deadline to file your federal and state income tax returns for 2022. (It is also, apparently, National Animal Crackers Day for those who celebrate.)", 'published': datetime.datetime(2023, 4, 18, 14, 15, 43), 'url': 'https://www.cnn.com/2023/04/18/success/tax-day-2023-file-irs/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230411161107-stressed-man-stock-super-169.jpeg'}
# {'title': 'Undocumented immigrants are paying their taxes today, too', 'content': "It's a surprising fact that's often overlooked in the immigration debate.", 'published': datetime.datetime(2023, 4, 18, 18, 29, 24), 'url': 'https://www.cnn.com/2023/04/18/us/undocumented-immigrants-taxes-cec/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/170328102815-dreamer-posts-taxes-super-169.jpg'}
# {'title': 'Opinion: Why millionaires like us want to pay more in taxes', 'content': "Tuesday is Tax Day in America, one of the most stressful days of the year, when many taxpayers will finally end their procrastination, file their federal returns, and hope for a refund from the IRS. But for many of the nation's wealthiest, it's just another Tuesday.", 'published': datetime.datetime(2023, 4, 17, 19, 32, 49), 'url': 'https://www.cnn.com/2023/04/17/opinions/us-tax-system-wealthy-disney-pearl/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/220112154235-filing-taxes-stock-super-169.jpeg'}
# {'title': "'World's longest' purpose-built cycling tunnel opens in Norway", 'content': "There are many ways to explore the seven mountains that surround the picturesque UNESCO World Heritage city of Bergen on Norway's fjord-studded west coast. The newest, however, might well be record-breaking.", 'published': datetime.datetime(2023, 4, 18, 10, 44, 27), 'url': 'https://www.cnn.com/travel/article/worlds-longest-cycling-tunnel/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418082736-01-fyllingsdalstunnelen-cycling-tunnel-super-169.jpeg'}
# {'title': 'Artist rejects photo prize after AI-generated image wins award', 'content': 'A German artist has rejected an award from a prestigious international photography competition after revealing that his submission was generated by Artificial Intelligence (AI).', 'published': datetime.datetime(2023, 4, 18, 15, 27, 54), 'url': 'https://www.cnn.com/style/article/ai-photo-win-sony-scli-intl/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418130247-tease-boris-eldagsen-ai-sony-photography-awards-super-169.jpg'}
# {'title': "These ships disappeared in Lake Superior a century ago. Watch as they're found again", 'content': 'The Great Lakes Shipwreck Historical Society has found two of three ships that sank in the same Lake Superior storm more than a century ago, locating one in 2021 and the other in 2022.', 'published': datetime.datetime(2023, 4, 18, 19, 29, 1), 'url': 'https://www.cnn.com/videos/travel/2023/04/18/century-old-shipwrecks-lake-superior-discovery-contd-orig-zt.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418114424-lostwreck2-super-169.jpg'}
# {'title': 'Erotic images of seniors show sex and intimacy in new light', 'content': "What does intimacy look like for seniors? There's no end to sex scenes and other steamy content featuring the young and unwrinkled, but past a certain age, popular culture largely draws a blank — or treats sex as a punchline.", 'published': datetime.datetime(2023, 4, 18, 3, 24, 57), 'url': 'https://www.cnn.com/style/article/marilyn-minter-artist-elder-sex/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230412135552-01b-marilyn-minter-elder-sex-crop-super-169.jpg'}
# {'title': "China's economy is off to a solid start, rising 4.5% in Q1 2023", 'content': "China's economy is off to a solid start in 2023 following its emergence from three years of strict pandemic restrictions.", 'published': datetime.datetime(2023, 4, 18, 7, 1, 12), 'url': 'https://www.cnn.com/2023/04/17/economy/china-gdp-q1-2023-intl-hnk/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418102017-china-economy-0418-super-169.jpg'}
# {'title': 'Even when wives make as much as husbands, they still do more at home', 'content': "• Four out of the five US metro areas with the lowest unemployment are in Florida. Here's why\n• Opinion: The overlooked problem with raising the retirement age for Social Security", 'published': datetime.datetime(2023, 4, 16, 17, 29, 49), 'url': 'https://www.cnn.com/2023/04/16/success/husbands-wives-earning-division-of-labor-pew-survey/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230414164019-husbands-wives-earnings-stock-super-169.jpg'}
# {'title': "McDonald's is upgrading its burgers", 'content': "McDonald's, which has been focusing on upgrading its core items to boost sales, is rolling out a series of changes designed to improve its signature burgers.", 'published': datetime.datetime(2023, 4, 17, 16, 31, 30), 'url': 'https://www.cnn.com/2023/04/17/business/mcdonalds-burgers/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230414175339-02-mcdonalds-burger-update-super-169.jpg'}
# {'title': 'Google-parent stock drops on fears it could lose search market share to AI-powered rivals', 'content': "Shares of Google-parent Alphabet fell more than 3% in early trading Monday after a report sparked concerns that its core search engine could lose market share to AI-powered rivals, including Microsoft's Bing.", 'published': datetime.datetime(2023, 4, 17, 15, 52, 19), 'url': 'https://www.cnn.com/2023/04/17/tech/google-ai-search-engine-stock-drop/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230202110718-02-google-bay-view-campus-0627-file-super-169.jpg'}
# {'title': 'Bidets save you money and reduce waste — we tested the best options out there', 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/reviews/best-bidets?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230414110242-best-bidets-border-lead-cnnu-super-169.jpg'}
# {'title': '50+ products to make your life easier and our planet cleaner', 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/home/editors-favorite-sustainable-products?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417094119-editors-picks-earth-week-new-lead-2023-super-169.jpg'}
# {'title': "Mother's Day is around the corner. Here are 50+ thoughtful gifts she'll love", 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/gifts/best-mothers-day-gifts-2023?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/220307152852-pillows-yana-lead-super-169.jpg'}
# {'title': 'A head-to-toe guide of how men should dress this spring, and where they should shop', 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/fashion/mens-spring-fashion-style-guide?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230314144004-underscored-todd-snyder-super-169.jpg'}
# {'title': '42 of the most useful travel products you can buy on Amazon', 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/travel/amazon-travel-products?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/211118095444-3-airtag-travel-companion-luggage-cnn-underscored-super-169.jpg'}
# {'title': 'The 7 best high-yield savings accounts of April 2023', 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/money/high-yield-savings-accounts?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230410125454-cit-bank-dvr-super-169.jpg'}
# {'title': "Taxes are due tomorrow. Here's how to file for an extension", 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/money/how-to-file-taxes?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/220623115617-underscored-airfly-review-lead-super-169.jpg'}
# {'title': "Composting is an easy way to reduce food waste. Here's how to do it", 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/home/how-to-compost-at-home?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230413112656-underscored-updated-lead-joey-gonzalez-super-169.jpg'}
# {'title': "We stopped using aluminum foil for cooking and you should too. Here's what to use instead", 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/reviews/mmmat-silicone-mats?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230414111853-earth-week-2023-sustainable-swaps-mm-mat-super-169.jpg'}
# {'title': 'The beloved Dyson Supersonic hair dryer is at its lowest price ever', 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/deals/dyson-supersonic-sale-2023-04-17?iid=CNNUnderscoredHPcontainer?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230405144728-stouchi-mount-on-laptop-at-angle-lead-cnnu-super-169.jpg'}
# {'title': "Everything you need to know about Way Day 2023, Wayfair's biggest sale of the year", 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/deals/wayfair-way-day-2023-04-17?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/191108140512-underscored-wayfair-lead-super-169.jpg'}
# {'title': 'The 10 best Amazon deals to shop this week', 'content': '', 'published': None, 'url': 'https://www.cnn.com/cnn-underscored/deals/best-amazon-deals-2023-04-12?iid=CNNUnderscoredHPcontainer', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/220302145616-petfavs-stephanie---casper-dog-bed--super-169.jpg'}
# {'title': 'Mifepristone saved my life', 'content': "The ruling earlier this month by a Texas federal judge to suspend the US Food and Drug Administration's approval of a drug that is used frequently for medication abortions, is very personal for me.", 'published': datetime.datetime(2023, 4, 18, 11, 30), 'url': 'https://www.cnn.com/2023/04/18/opinions/medication-abortion-mifepristone-miscarriage-jones-ctpr/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230105123125-medication-abortion-process-wellness-super-169.jpg'}
# {'title': 'The 2024 presidential alternative many voters will want', 'content': '', 'published': None, 'url': 'https://www.cnn.com/2023/04/18/opinions/2024-presidential-election-alternative-voters-lieberman', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418094726-presidential-ticket-2024-opinion-super-169.jpg'}
# {'title': "Why isn't the House Judiciary Committee looking into Thomas?", 'content': 'On Monday, the GOP-controlled House Judiciary Committee — chaired by Donald Trump ally Rep. Jim Jordan — is set to hold a field hearing in New York City called "Victims of Violent Crime in Manhattan." A statement bills the hearing as an examination of how, the Judiciary Committee says, Manhattan District Attorney Alvin Bragg\'s policies have "led to an increase in violent crime and a dangerous community for New York City residents."', 'published': datetime.datetime(2023, 4, 17, 11, 37, 37), 'url': 'https://www.cnn.com/2023/04/17/opinions/jim-jordan-clarence-thomas-judiciary-committee-obeidallah/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230406092847-justice-clarence-thomas-221007-super-169.jpg'}
# {'title': 'Top secrets come spilling out', 'content': 'In 1917, British analysts deciphered a coded message the German foreign minister sent to one of his country\'s diplomats vowing to begin "unrestricted submarine warfare" and seeking to win over Mexico with a promise to "reconquer the lost territory in Texas, New Mexico and Arizona" if the US entered the world war. When it became public, the Zimmerman Telegram caused a sensation, helping propel the US into the conflict against Germany.', 'published': datetime.datetime(2023, 4, 16, 11, 22, 36), 'url': 'https://www.cnn.com/2023/04/16/opinions/top-secrets-come-spilling-out-opinion-column-galant/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230413145300-02-jack-teixeira-super-169.jpg'}
# {'title': 'How did Sudan go from casting off despotic rule to this?', 'content': 'Four years ago, almost to the day, the people of Sudan were celebrating a revolution after overthrowing longtime dictator Omar al-Bashir. Now the East African country faces the possibility of a complete collapse similar to the chaos we see today in Yemen or Libya.', 'published': datetime.datetime(2023, 4, 17, 22, 45, 23), 'url': 'https://www.cnn.com/2023/04/17/opinions/sudan-revolution-to-civil-war-lynch/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417104918-01-sudan-unrest-041723-super-169.jpg'}
# {'title': "Michelle Yeoh set to return in new 'Star Trek' movie", 'content': 'Live long and prosper, Michelle Yeoh.', 'published': datetime.datetime(2023, 4, 18, 19, 11, 23), 'url': 'https://www.cnn.com/2023/04/18/entertainment/michelle-yeoh-star-trek-section-31/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418135551-michelle-yeoh-star-trek-discovery-file-super-169.jpg'}
# {'title': "Recap: 'Succession' finds dark humor in the aftershocks", 'content': 'After the shock came the aftershocks, the power vacuum, and perhaps most significantly and impressively, the laughs, as "Succession" pivoted to face life after Logan Roy, in an episode that finally put the HBO show\'s title into full flower.', 'published': datetime.datetime(2023, 4, 17, 2, 28, 12), 'url': 'https://www.cnn.com/2023/04/16/entertainment/succession-season-4-episode-4-recap/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230126123530-01-succession-season-4-super-169.jpg'}
# {'title': "'Yellowjackets' leans hard into '90s music nostalgia, and we're here for it", 'content': 'Of the many dark gifts Showtime\'s eerie hit series "Yellowjackets" serves up for us, the juiciest this season is by far the music.', 'published': datetime.datetime(2023, 5, 1, 23, 2, 4), 'url': 'https://www.cnn.com/2023/04/14/entertainment/yellowjackets-90s-music/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230413192945-03-yellowjackets-s2e3-super-169.jpg'}
# {'title': "Jeremy Renner revisits 'the amazing group of people' who helped him recover from his accident", 'content': "Jeremy Renner is continuing his recovery after his devastating snowplow accident in January, and recognizing those who've helped him along the way.", 'published': datetime.datetime(2023, 4, 16, 19, 4, 10), 'url': 'https://www.cnn.com/2023/04/16/entertainment/jeremy-renner-update/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230416142440-03-jeremy-renner-041123-restricted-super-169.jpg'}
# {'title': "Review: 'Barry' takes a whack at its farewell season", 'content': '"Barry" has taken chances from the very beginning, which is certainly true of a fourth and final season that picks up where the third left off, with its hitman-turned-wannabe actor getting arrested. That paves the way for an even darker season that accentuates the show\'s ensemble aspect while leaning a little too heavily on blurring lines with flights of fancy.', 'published': datetime.datetime(2023, 4, 14, 12, 33, 8), 'url': 'https://www.cnn.com/2023/04/14/entertainment/barry-season-4-review/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230412113212-01-barry-season-4-super-169.jpg'}
# {'title': "Costco's gold bars are selling out fast as shoppers eye financial security", 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/eea1067b4d236d6ea531b3add498e85e.jpg" /><p>In a striking display of <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://qz.com/costco-platinum-bars-gold-and-silver-retail-consumers-1851663436" rel="noopener noreferrer" target="_blank">shifting</a> consumer behavior, Costco (<a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://qz.com/quote/COST" rel="noopener noreferrer" target="_blank">COST</a>) Wholesale gold bars are disappearing from shelves faster than they can be restocked. </p><p><a href="https://qz.com/costco-gold-bars-metal-silver-platinum-retail-consumer-1851667327">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 22, 15), 'url': 'https://qz.com/costco-gold-bars-metal-silver-platinum-retail-consumer-1851667327', 'media_url': None}
# {'title': 'FTX shareholders could get $1 billion after crypto firm is cleared to fully repay customers', 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/a0da3871c4dbf126245cc0ae4a47b7bd.jpg" /><p>A judge has reportedly approved payments to customers of collapsed crypto exchange FTX — and its shareholders could get $1 billion in seized assets. </p><p><a href="https://qz.com/ftx-shareholders-billion-seized-crypto-exchange-sbf-1851667188">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 20, 51), 'url': 'https://qz.com/ftx-shareholders-billion-seized-crypto-exchange-sbf-1851667188', 'media_url': None}
# {'title': 'Christine McVie’s Fleetwood Mac scrapbook, Dianne Feinstein’s books, and an iconic Marilyn Monroe portrait: this week’s auction block roundup', 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/b08a23f0ad44536bd2d771ef878965b7.jpg" /><p>Each week Quartz highlights the upcoming and ongoing sales at auction houses across the world. Among the items available are works of art, historical artifacts, and pop culture memorabilia that collectors won’t want to miss out on. While some of these objects go for millions, others are simultaneously affordable and…</p><p><a href="https://qz.com/this-week-s-auction-block-roundup-1851667217">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 20, 19), 'url': 'https://qz.com/this-week-s-auction-block-roundup-1851667217', 'media_url': None}
# {'title': "McDonald's is suing Tyson Foods for allegedly choking the supply chain to raise prices", 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/c05075daf60d07669013f7602b944647.jpg" /><p><a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://qz.com/mcdonalds-chicken-big-mac-retail-consumers-1851664859" rel="noopener noreferrer" target="_blank">McDonald’s</a> has filed a <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://fingfx.thomsonreuters.com/gfx/legaldocs/jnvwjeeakpw/McDonald\'s%20v%20Cargill%20-%20EDNY%20-%2020241004.pdf" rel="noopener noreferrer" target="_blank">lawsuit</a> against Tyson Foods (<a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://qz.com/quote/TSN" rel="noopener noreferrer" target="_blank">TSN</a>), JBS, and other  major meat processing companies, accusing them of colluding for years to limit beef supplies.<br /></p><p><a href="https://qz.com/mcdonalds-sues-tyson-foods-jbs-cargill-beef-supply-1851667117">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 19, 56), 'url': 'https://qz.com/mcdonalds-sues-tyson-foods-jbs-cargill-beef-supply-1851667117', 'media_url': None}
# {'title': "Donald Trump's plans would cut taxes on the richest 5% of America — and raise them for everyone else", 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/003c6e4fa140321f294be54cd74a46d5.jpg" /><p>Former President Donald Trump has promised to slash — or scrap — a lot of taxes. But his plans to hike tariffs on imports would “more than offset” those tax cuts for all but the richest 5% of Americans, according to a <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://itep.org/a-distributional-analysis-of-donald-trumps-tax-plan-2024/" rel="noopener noreferrer" target="_blank">new analysis</a>. </p><p><a href="https://qz.com/donald-trump-tax-cuts-wealthiest-americans-tarrifs-1851667005">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 19, 7), 'url': 'https://qz.com/donald-trump-tax-cuts-wealthiest-americans-tarrifs-1851667005', 'media_url': None}
# {'title': 'Super Micro Computer stock surges 15% on big AI demand', 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/b0757900a5910da0c80f614a0b1b05db.jpg" /><p>Server company Super Micro Computer (<a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://qz.com/quote/SMCI" rel="noopener noreferrer" target="_blank">SMCI</a>) unveiled a new liquid cooling solution for AI data centers on Monday, while also revealing it’s shipping over 100,000 graphics processing units (GPUs) quarterly — news that sent its stock climbing more than 15% in midday trading.</p><p><a href="https://qz.com/super-micro-computer-stock-shares-surge-ai-demand-gpu-1851667019">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 19, 5, 36), 'url': 'https://qz.com/super-micro-computer-stock-shares-surge-ai-demand-gpu-1851667019', 'media_url': None}
# {'title': 'A hot meal on a transatlantic JetBlue flight will now cost extra', 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/4d23d5624d6070712e3d63ca64bc48a1.jpg" /><p>JetBlue is making a big change to its transatlantic flight offerings. CNN (<a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://qz.com/quote/WBD" rel="noopener noreferrer" target="_blank">WBD</a>) reports that the company’s “core” fares flying to Europe and the U.K. will <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://www.cnn.com/2024/10/07/travel/jetblue-drops-hot-meals-economy-passengers/index.html" rel="noopener noreferrer" target="_blank">no longer come</a> with hot meals.</p><p><a href="https://qz.com/jetblue-transatlantic-hot-food-cut-1851667000">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 18, 28), 'url': 'https://qz.com/jetblue-transatlantic-hot-food-cut-1851667000', 'media_url': None}
# {'title': 'EV chargers that feel more like a gas station are coming', 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/d58fbe47c8ba02fee3d888b4ff0d6805.png" /><p>One major key to EV adoption is creating a comprehensive charging network. Not only does it have to be <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://jalopnik.com/ev-charging-should-be-so-much-easier-1850784127?_gl=1*169sb8c*_ga*MTM0NDQ4ODA2My4xNzIyMzc4NDE0*_ga_V4QNJTT5L0*MTcyODMwMTQ1Ny4xMTguMS4xNzI4MzA1Njk0LjU3LjAuMA..">convenient</a>, it has to be <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://jalopnik.com/non-tesla-evs-are-having-a-hard-time-using-supercharger-1851662200?_gl=1*169sb8c*_ga*MTM0NDQ4ODA2My4xNzIyMzc4NDE0*_ga_V4QNJTT5L0*MTcyODMwMTQ1Ny4xMTguMS4xNzI4MzA1Njk0LjU3LjAuMA..">appealing</a>.  One company is making a valiant attempt with its new gas station-like EV chargers. </p><p><a href="https://qz.com/rove-ev-charger-gas-station-california-1851667059">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 18, 21, 41), 'url': 'https://qz.com/rove-ev-charger-gas-station-california-1851667059', 'media_url': None}
# {'title': "Bankrupt EV startup Fisker left its abandoned headquarters in 'complete disarray'", 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/1b6194a6700ba7915bcebc87bf5f1507.png" /><p><a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://jalopnik.com/fisker-is-dead-but-its-legal-troubles-are-just-beginnin-1851666516">Fisker can’t seem to do anything right</a> – and that includes closing up shop. Apparently, the <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://jalopnik.com/fisker-resorts-to-fixing-customer-cars-with-preproducti-1851454868?_gl=1*1un33re*_ga*MTI1NTUyODY0OS4xNjgzODI2NTIz*_ga_V4QNJTT5L0*MTcyODMxOTM1OC4xMzMuMS4xNzI4MzE5NTU3LjQ5LjAuMA..">La Palma, California headquarters</a> of <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://jalopnik.com/comedy-of-errors-led-to-fisker-s-bankruptcy-1851550234">the now-dead automaker</a> was abandoned and left in “complete disarray” with full-size <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://jalopnik.com/gm-clay-sculptor-buys-the-shittiest-car-in-the-junkyard-1844575033">clay models,</a> automotive equipment, <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://jalopnik.com/real-world-solid-state-batteries-are-here-and-its-blowi-1851595209">EV batteries </a>and hazardous waste left behind.</p><p><a href="https://qz.com/fisker-bankruptcy-evs-headquarters-lawsuit-1851667041">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 18, 18, 10), 'url': 'https://qz.com/fisker-bankruptcy-evs-headquarters-lawsuit-1851667041', 'media_url': None}
# {'title': 'A Frontier Airlines flight trailed flames as it landed', 'content': '<video loop="" poster="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/76a04059b0e2d273d3844bf96c600130.jpg"><source src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/76a04059b0e2d273d3844bf96c600130.mp4" type="video/mp4" /></video><p>Clapping when a flight lands may be a fading tradition, but it’s fully deserved some days. Passengers on <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://jalopnik.com/frontier-launches-149-monthly-unlimited-flight-pass-wi-1850696796">a Frontier Airlines flight</a> certainly had a reason for applause on Saturday after the flight from San Diego trailed flames from its landing gear while landing at <a class="sc-1out364-0 dPMosf sc-145m8ut-0 lcFFec js_link" href="https://jalopnik.com/passenger-threatened-to-bomb-vegas-airport-because-he-c-1851647377">Harry Reid International Airport</a> in Las Vegas. All…</p><p><a href="https://qz.com/frontier-airlines-flight-flames-land-las-vegas-airbus-1851667033">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 18, 14, 32), 'url': 'https://qz.com/frontier-airlines-flight-flames-land-las-vegas-airbus-1851667033', 'media_url': None}
# {'title': 'A classic Hamptons home, cliffside Beverly Hills bungalow and mansion-sized Manhattan townhouse: This week’s real estate roundup', 'content': '<img class="type:primaryImage" src="https://i.kinja-img.com/image/upload/c_fit,q_80,w_636/5c7b422cd1d4376df2c5bd5cab800146.jpg" /><p>Each week Quartz highlights the most luxurious real estate listings across the country. These properties feature remarkable views, enviable locations, and lavish amenities — and they’re all on the market right now. Check out the best homes that are available with upcoming open houses.<br /></p><p><a href="https://qz.com/most-fabulous-real-estate-listings-oct-2024-1851666947">Read more...</a></p>', 'published': datetime.datetime(2024, 10, 7, 17, 58), 'url': 'https://qz.com/most-fabulous-real-estate-listings-oct-2024-1851666947', 'media_url': None}
# ...
# {'title': 'Rex Tillerson says continue diplomacy with North Korea ‘until first bomb drops’', 'content': 'That statement comes despite President Donald Trump\'s tweets a couple of weeks ago that his chief envoy was "wasting his time" trying to negotiate with "Little Rocket Man," a mocking nickname Trump has given the nuclear-armed nation\'s leader, Kim Jong Un.', 'published': datetime.datetime(2017, 10, 16, 11, 8), 'url': 'http://www.pbs.org/newshour/rundown/rex-tillerson-says-continue-diplomacy-north-korea-first-bomb-drops/', 'media_url': 'http://d3i6fh83elv35t.cloudfront.net/newshour/wp-content/uploads/2017/08/statedept2-1024x618.jpg'}
# {'title': 'Iraqi, Kurdish forces in standoff, weeks after Kurdish vote for independence', 'content': 'Iraqi army and Kurdish troops are in a standoff in Kirkuk, a city located in the Kurdistan region, which voted for independence from Iraq last month. Kirkuk holds 10 percent of Iraq’s oil reserves. Washington Post reporter Loveday Morris, who is covering the standoff, joins Hari Sreenivasan via Skype from Baghdad.', 'published': datetime.datetime(2017, 10, 15, 20, 33, 23), 'url': 'http://www.pbs.org/newshour/bb/iraqi-kurdish-forces-standoff-weeks-kurdish-vote-independence/', 'media_url': 'http://d3i6fh83elv35t.cloudfront.net/newshour/wp-content/uploads/2017/10/RTS1GDM5-1024x626.jpg'}
# {'title': 'South Sudan civil war causes Africa’s worst refugee crisis', 'content': 'South Sudan’s four-year civil war has left half of the nation’s population, 6 million people, in need of humanitarian aid and caused one of the world’s worst refugee crises. With support from the U.S. Holocaust Memorial Museum’s Center for the Prevention of Genocide, NewsHour Weekend Special Correspondent Simona Foltyn and journalist Jason Patinkin traveled to Uganda to meet people desperate for asylum.', 'published': datetime.datetime(2017, 10, 15, 19, 26, 17), 'url': 'http://www.pbs.org/newshour/bb/south-sudan-civil-war-causes-africas-worst-refugee-crisis/', 'media_url': 'http://d3i6fh83elv35t.cloudfront.net/newshour/wp-content/uploads/2017/10/RTX3905F-1024x683.jpg'}
# {'title': 'Hundreds dead after massive truck bomb strikes Mogadishu', 'content': "At least 231 people were killed and hundreds more wounded after a massive truck bomb on Saturday struck Somalia's capital city of Mogadishu.", 'published': datetime.datetime(2017, 10, 15, 16, 27, 49), 'url': 'http://www.pbs.org/newshour/rundown/hundreds-dead-massive-truck-bomb-strikes-mogadishu/', 'media_url': 'http://d3i6fh83elv35t.cloudfront.net/newshour/wp-content/uploads/2017/10/RTS1GGFV-1024x652.jpg'}
# {'title': 'Column: Why reporting from South Sudan is so difficult — and critically needed', 'content': 'The war has had a devastating impact on South Sudanese communities, but much of it has remained out of the limelight of international media.', 'published': datetime.datetime(2017, 10, 15, 14, 27, 40), 'url': 'http://www.pbs.org/newshour/updates/reporters-notebook-reporting-south-sudan-difficult-critically-needed/', 'media_url': 'http://d3i6fh83elv35t.cloudfront.net/newshour/wp-content/uploads/2017/10/Simona-Foltyn-walks-down-a-mountain-slope-shortly-after-crossing-into-South-Sudan-1024x684.jpg'}
# {'title': "Modi's BJP ahead in Haryana election but trails in Kashmir", 'content': "PM Modi's party is leading in the northern state of Haryana but may fall short in Indian-administered Kashmir.", 'published': datetime.datetime(2024, 10, 8, 4, 10, 43), 'url': 'https://www.bbc.com/news/articles/cx24xkyg1qko', 'media_url': None}
# {'title': "Indian financial aid opens 'new chapter' with Maldives", 'content': 'The deal comes as the Maldives president visits Delhi after relations nosedived in recent months.', 'published': datetime.datetime(2024, 10, 7, 12, 24, 15), 'url': 'https://www.bbc.com/news/articles/cly4eq78k5qo', 'media_url': None}
# {'title': 'Why are there so many dropped catches at T20 World Cup?', 'content': "BBC Sport looks at the significant number of dropped catches at the Women's T20 World Cup so far and the possible explanations.", 'published': datetime.datetime(2024, 10, 6, 20, 1, 57), 'url': 'https://www.bbc.com/sport/cricket/articles/cg78yd0p088o', 'media_url': None}
# {'title': 'Climbers rescued after three days in the Himalayas', 'content': 'A British climber who went missing in the Himalayas has spoken of her relief after surviving for two days in "brutal" conditions that put her life in danger.', 'published': datetime.datetime(2024, 10, 6, 16, 14, 26), 'url': 'https://www.bbc.com/news/articles/c93y147z4pdo', 'media_url': None}
# {'title': 'Maldives president visits India amid trouble in tourist paradise', 'content': 'President Muizzu is visiting India at a time when his country is staring at an economic crisis.', 'published': datetime.datetime(2024, 10, 6, 0, 10, 51), 'url': 'https://www.bbc.com/news/articles/ce8vz8j60kno', 'media_url': None}
# {'title': 'The Polish artist who painted Hindu gods in Indian palaces', 'content': 'Stefan Norblin painted beautiful murals in the art deco style for Indian maharajas in the 1940s.', 'published': datetime.datetime(2024, 10, 4, 23, 21, 43), 'url': 'https://www.bbc.com/news/articles/c8xe17pegrno', 'media_url': None}
# {'title': "India government says criminalising marital rape 'excessively harsh'", 'content': "The government has opposed petitions in the country's top court that seek criminalisation of marital rape.", 'published': datetime.datetime(2024, 10, 4, 6, 32, 38), 'url': 'https://www.bbc.com/news/articles/c80r38yeempo', 'media_url': None}
# {'title': "India's foreign minister to visit Pakistan for the first time since 2015", 'content': "India's foreign minister S Jaishankar will be attending a regional meeting in Pakistan this month.", 'published': datetime.datetime(2024, 10, 4, 12, 41, 38), 'url': 'https://www.bbc.com/news/articles/c0lw9pdw400o', 'media_url': None}
# {'title': 'How India became a Test cricket powerhouse', 'content': 'More than 90 years after its first Test match, India boasts more victories in the format than losses.', 'published': datetime.datetime(2024, 10, 3, 21, 27, 11), 'url': 'https://www.bbc.com/news/articles/cz6w0lygq22o', 'media_url': None}
# {'title': "India's iconic tramcars set to ride into Kolkata sunset", 'content': "Kolkata's iconic trams are in danger of being shut down entirely. But activists are fighting back.", 'published': datetime.datetime(2024, 10, 1, 23, 30, 25), 'url': 'https://www.bbc.com/news/articles/ckgn4mzn224o', 'media_url': None}
# {'title': 'My mission is to take Tamil music global, says Sid Sriram', 'content': 'The Indian-born, American-raised artist is going to perform his biggest solo UK show.', 'published': datetime.datetime(2024, 10, 6, 0, 25, 44), 'url': 'https://www.bbc.com/news/articles/cvgwwqpdj74o', 'media_url': None}
# {'title': "India's top court saves a poor student's college dream", 'content': 'Atul Kumar missed the deadline to pay his college fee by a few seconds - then a court stepped in to help him.', 'published': datetime.datetime(2024, 10, 3, 9, 24, 47), 'url': 'https://www.bbc.com/news/articles/cx25nq12n10o', 'media_url': None}
# {'title': "The 'mastermind' behind India's biggest jailbreak", 'content': 'Nearly 20 years ago, 389 men escaped from an Indian jail, led by a man believed to have planned the breakout.', 'published': datetime.datetime(2024, 10, 1, 1, 48, 53), 'url': 'https://www.bbc.com/news/articles/c1dd9rj3vmyo', 'media_url': None}
# {'title': 'The world’s diamond polishing capital feels Ukraine war impact', 'content': "Wars and recession in key Western markets have left India's diamond industry workers distraught and jobless.", 'published': datetime.datetime(2024, 9, 30, 1, 4, 21), 'url': 'https://www.bbc.com/news/articles/c1e866ypp1zo', 'media_url': None}
# {'title': 'Sold out in minutes, resold for millions: Coldplay tickets spark outrage in India', 'content': "Coldplay's concerts in Mumbai sold out in minutes and now resellers are charging up to $10,000 for a ticket.", 'published': datetime.datetime(2024, 9, 29, 1, 24, 50), 'url': 'https://www.bbc.com/news/articles/c99v12e3yj4o', 'media_url': None}
# {'title': 'A famed holy sweet in an unsavoury row in India', 'content': 'The famous Tirupati temple laddus are prized by devotees who consider them god’s blessing.', 'published': datetime.datetime(2024, 9, 26, 21, 41, 55), 'url': 'https://www.bbc.com/news/articles/cglkenxgd5xo', 'media_url': None}
# {'title': "Your essential guide to the ICC Women's T20 World Cup", 'content': "The Women's T20 World Cup in the United Arab Emirates starts on 3 October - here's everything you need to know about the ninth edition.", 'published': datetime.datetime(2024, 10, 1, 7, 59, 27), 'url': 'https://www.bbc.com/sport/cricket/articles/c99vp4yyyyxo', 'media_url': None}
# {'title': 'The Kashmiri politician whose return from jail ruffled feathers', 'content': 'A court has allowed jailed lawmaker Engineer Rashid to return to Kashmir to campaign in regional polls.', 'published': datetime.datetime(2024, 9, 26, 1, 0, 4), 'url': 'https://www.bbc.com/news/articles/cgj4l01q9jgo', 'media_url': None}
# {'title': "Death of Indian employee sparks debate on 'toxic work culture'", 'content': 'Anna Perayil\'s parents allege she died four months after starting a job because of "overwhelming work stress".', 'published': datetime.datetime(2024, 9, 24, 21, 39, 31), 'url': 'https://www.bbc.com/news/articles/c0kjgp4jr5yo', 'media_url': None}
# {'title': 'Tigers and crocs make mangrove preservation tough work', 'content': 'To help preserve mangrove forests researchers have to take on demanding field work.', 'published': datetime.datetime(2024, 9, 23, 23, 9, 2), 'url': 'https://www.bbc.com/news/articles/crrldyvqe4xo', 'media_url': None}
# {'title': 'How Punjabi megastar Diljit Dosanjh is inspiring the next gen', 'content': 'The biggest Punjabi singer in the world brings his Dil-Luminati tour to the UK.', 'published': datetime.datetime(2024, 9, 21, 23, 51, 46), 'url': 'https://www.bbc.com/news/articles/cwy9gln6lz6o', 'media_url': None}
# {'title': "Hema committee report: Why are India's biggest film stars silent?", 'content': 'The stars’ silence on a report exposing poor working conditions and sexual harassment in Kerala’s film industry is deafening, say critics.', 'published': datetime.datetime(2024, 9, 19, 21, 39, 3), 'url': 'https://www.bbc.com/news/articles/cn9dgjd8rewo', 'media_url': None}
# {'title': 'Volunteers dying as Russia’s war dead tops 70,000', 'content': 'The governments of India and Nepal have called on Moscow to stop sending their citizens to Ukraine and repatriate the bodies of the dead.', 'published': datetime.datetime(2024, 9, 19, 23, 12, 45), 'url': 'https://www.bbc.com/news/articles/cjr3255gpjgo', 'media_url': None}
# {'title': 'Why hundreds of Samsung workers are protesting in India', 'content': 'About 1500 workers in Tamil Nadu state have been striking work for the past 11 days.', 'published': datetime.datetime(2024, 9, 19, 13, 51, 52), 'url': 'https://www.bbc.com/news/articles/c7488w85n00o', 'media_url': None}
# {'title': "'Please save me': The Indians duped into fighting for Russia", 'content': 'Dozens of Indian men have been discharged from the Russian army and are making their way home.', 'published': datetime.datetime(2024, 9, 18, 8, 11, 6), 'url': 'https://www.bbc.com/news/articles/cly6ve2x72xo', 'media_url': None}
# {'title': 'After a decade, Kashmir votes in historic elections', 'content': "This is the first assembly election since PM Modi's government revoked Kashmir's special status in 2019.", 'published': datetime.datetime(2024, 9, 16, 8, 31, 13), 'url': 'https://www.bbc.com/news/articles/cpw84kv9q8yo', 'media_url': None}
# {'title': 'The German woman who helped build an Indian university', 'content': 'Gerda Philipsborn left her home in Germany to help her three Indian friends set up Jamia Millia Islamia.', 'published': datetime.datetime(2024, 9, 16, 21, 41, 27), 'url': 'https://www.bbc.com/news/articles/cn020ywgx2yo', 'media_url': None}
# {'title': 'Bangladesh leader’s ‘megaphone diplomacy’ irks India', 'content': 'Ties between India and Bangladesh remain frosty more than a month after Sheikh Hasina was ousted from power.', 'published': datetime.datetime(2024, 9, 12, 21, 41, 41), 'url': 'https://www.bbc.com/news/articles/cz6xqyzzdxgo', 'media_url': None}
# {'title': "India's oldest trams may soon be brought to a halt", 'content': 'Authorities in the eastern city of Kolkata announced plans to discontinue its iconic trams first set up in 1873.', 'published': datetime.datetime(2024, 10, 1, 12, 27, 53), 'url': 'https://www.bbc.com/news/articles/cr54qr64n1qo', 'media_url': None}
# {'title': "Kolkata night protest: 'Today I witnessed history'", 'content': "A young woman was among thousands who took part in a march in India's West Bengal. This is what she saw.", 'published': datetime.datetime(2024, 8, 15, 10, 22, 1), 'url': 'https://www.bbc.com/news/videos/ce3106yz19do', 'media_url': None}
# {'title': 'Watch: Thousands of women protest about rape and murder of doctor in India', 'content': "Women led a march in West Bengal state after a female doctor's brutal rape and murder last week.", 'published': datetime.datetime(2024, 8, 15, 8, 56, 44), 'url': 'https://www.bbc.com/news/videos/czx67lknn54o', 'media_url': None}
# {'title': 'Watch: Building collapses into river in Himachal Pradesh', 'content': 'No-one was injured in the incident, which took place due to heavy rainfall.', 'published': datetime.datetime(2024, 8, 1, 7, 44, 51), 'url': 'https://www.bbc.com/news/videos/c1vdw9546wwo', 'media_url': None}
# {'title': 'Watch: Blue screens, queues and airport delays worldwide', 'content': 'Many flights have been grounded, with huge queues and delays at airports all over the world.', 'published': datetime.datetime(2024, 7, 19, 11, 51, 9), 'url': 'https://www.bbc.com/news/videos/cz7ejpld988o', 'media_url': None}
# {'title': 'Lavish Ambani wedding divides opinions in India', 'content': 'The noise around the lavish wedding has drawn public fascination - and ire.', 'published': datetime.datetime(2024, 7, 12, 13, 22, 41), 'url': 'https://www.bbc.com/news/videos/cgr5073mz74o', 'media_url': None}
# {'title': 'Former PMs, film and sports stars join Ambani wedding', 'content': "Tony Blair and Boris Johnson were among guests to arrive at the wedding of a billionaire's son.", 'published': datetime.datetime(2024, 7, 12, 21, 10, 1), 'url': 'https://www.bbc.com/news/videos/cv2gnv34kyeo', 'media_url': None}
# {'title': 'WATCH: Families mourn victims of deadly India crush', 'content': 'At least 121 people, mostly women, were killed in the crush at a religious event in northern India.', 'published': datetime.datetime(2024, 7, 3, 9, 42, 54), 'url': 'https://www.bbc.com/news/videos/cw4ypql875ko', 'media_url': None}
# {'title': 'Watch: Delhi airport roof collapses due to heavy rain', 'content': 'The incident has left one person dead and injured four others.', 'published': datetime.datetime(2024, 6, 28, 7, 43, 43), 'url': 'https://www.bbc.com/news/videos/c134zdz2nnro', 'media_url': None}
# {'title': "What worked for India's Modi - and what didn’t?", 'content': "Indian Prime Minister Narendra Modi and his party have won the most seats in this year's election.", 'published': datetime.datetime(2024, 6, 4, 15, 32, 32), 'url': 'https://www.bbc.com/news/articles/ce442577v35o', 'media_url': None}
# {'title': 'Arrests, accusations and AI: India’s election unpacked', 'content': 'On 4 June, Indians will find out who governs their country for the next five years.', 'published': datetime.datetime(2024, 6, 1, 23, 7, 59), 'url': 'https://www.bbc.com/news/videos/cqqq2g653gro', 'media_url': None}

# %%
articles_formatted = []
for article in articles:
    articles_formatted.append(
        {'title':article['title'],
        'description':article['content']},        
        )
    
articles_formatted
# Out:
# [{'title': "Modi's BJP ahead in Haryana election but trails in Kashmir",
#   'description': "PM Modi's party is leading in the northern state of Haryana but may fall short in Indian-administered Kashmir."},
#  {'title': "Indian financial aid opens 'new chapter' with Maldives",
#   'description': 'The deal comes as the Maldives president visits Delhi after relations nosedived in recent months.'},
#  {'title': 'Why are there so many dropped catches at T20 World Cup?',
#   'description': "BBC Sport looks at the significant number of dropped catches at the Women's T20 World Cup so far and the possible explanations."},
#  {'title': 'Climbers rescued after three days in the Himalayas',
#   'description': 'A British climber who went missing in the Himalayas has spoken of her relief after surviving for two days in "brutal" conditions that put her life in danger.'},
#  {'title': 'Maldives president visits India amid trouble in tourist paradise',
#   'description': 'President Muizzu is visiting India at a time when his country is staring at an economic crisis.'},
#  {'title': 'The Polish artist who painted Hindu gods in Indian palaces',
#   'description': 'Stefan Norblin painted beautiful murals in the art deco style for Indian maharajas in the 1940s.'},
#  {'title': "India government says criminalising marital rape 'excessively harsh'",
#   'description': "The government has opposed petitions in the country's top court that seek criminalisation of marital rape."},
#  {'title': "India's foreign minister to visit Pakistan for the first time since 2015",
#   'description': "India's foreign minister S Jaishankar will be attending a regional meeting in Pakistan this month."},
#  {'title': 'How India became a Test cricket powerhouse',
#   'description': 'More than 90 years after its first Test match, India boasts more victories in the format than losses.'},
#  {'title': "India's iconic tramcars set to ride into Kolkata sunset",
#   'description': "Kolkata's iconic trams are in danger of being shut down entirely. But activists are fighting back."},
#  {'title': 'My mission is to take Tamil music global, says Sid Sriram',
#   'description': 'The Indian-born, American-raised artist is going to perform his biggest solo UK show.'},
#  {'title': "India's top court saves a poor student's college dream",
#   'description': 'Atul Kumar missed the deadline to pay his college fee by a few seconds - then a court stepped in to help him.'},
#  {'title': "The 'mastermind' behind India's biggest jailbreak",
#   'description': 'Nearly 20 years ago, 389 men escaped from an Indian jail, led by a man believed to have planned the breakout.'},
#  {'title': 'The world’s diamond polishing capital feels Ukraine war impact',
#   'description': "Wars and recession in key Western markets have left India's diamond industry workers distraught and jobless."},
#  {'title': 'Sold out in minutes, resold for millions: Coldplay tickets spark outrage in India',
#   'description': "Coldplay's concerts in Mumbai sold out in minutes and now resellers are charging up to $10,000 for a ticket."},
#  {'title': 'A famed holy sweet in an unsavoury row in India',
#   'description': 'The famous Tirupati temple laddus are prized by devotees who consider them god’s blessing.'},
#  {'title': "Your essential guide to the ICC Women's T20 World Cup",
#   'description': "The Women's T20 World Cup in the United Arab Emirates starts on 3 October - here's everything you need to know about the ninth edition."},
#  {'title': 'The Kashmiri politician whose return from jail ruffled feathers',
#   'description': 'A court has allowed jailed lawmaker Engineer Rashid to return to Kashmir to campaign in regional polls.'},
#  {'title': "Death of Indian employee sparks debate on 'toxic work culture'",
#   'description': 'Anna Perayil\'s parents allege she died four months after starting a job because of "overwhelming work stress".'},
#  {'title': 'Tigers and crocs make mangrove preservation tough work',
#   'description': 'To help preserve mangrove forests researchers have to take on demanding field work.'},
#  {'title': 'How Punjabi megastar Diljit Dosanjh is inspiring the next gen',
#   'description': 'The biggest Punjabi singer in the world brings his Dil-Luminati tour to the UK.'},
#  {'title': "Hema committee report: Why are India's biggest film stars silent?",
#   'description': 'The stars’ silence on a report exposing poor working conditions and sexual harassment in Kerala’s film industry is deafening, say critics.'},
#  {'title': 'Volunteers dying as Russia’s war dead tops 70,000',
#   'description': 'The governments of India and Nepal have called on Moscow to stop sending their citizens to Ukraine and repatriate the bodies of the dead.'},
#  {'title': 'Why hundreds of Samsung workers are protesting in India',
#   'description': 'About 1500 workers in Tamil Nadu state have been striking work for the past 11 days.'},
#  {'title': "'Please save me': The Indians duped into fighting for Russia",
#   'description': 'Dozens of Indian men have been discharged from the Russian army and are making their way home.'},
#  {'title': 'After a decade, Kashmir votes in historic elections',
#   'description': "This is the first assembly election since PM Modi's government revoked Kashmir's special status in 2019."},
#  {'title': 'The German woman who helped build an Indian university',
#   'description': 'Gerda Philipsborn left her home in Germany to help her three Indian friends set up Jamia Millia Islamia.'},
#  {'title': 'Bangladesh leader’s ‘megaphone diplomacy’ irks India',
#   'description': 'Ties between India and Bangladesh remain frosty more than a month after Sheikh Hasina was ousted from power.'},
#  {'title': "India's oldest trams may soon be brought to a halt",
#   'description': 'Authorities in the eastern city of Kolkata announced plans to discontinue its iconic trams first set up in 1873.'},
#  {'title': "Kolkata night protest: 'Today I witnessed history'",
#   'description': "A young woman was among thousands who took part in a march in India's West Bengal. This is what she saw."},
#  {'title': 'Watch: Thousands of women protest about rape and murder of doctor in India',
#   'description': "Women led a march in West Bengal state after a female doctor's brutal rape and murder last week."},
#  {'title': 'Watch: Building collapses into river in Himachal Pradesh',
#   'description': 'No-one was injured in the incident, which took place due to heavy rainfall.'},
#  {'title': 'Watch: Blue screens, queues and airport delays worldwide',
#   'description': 'Many flights have been grounded, with huge queues and delays at airports all over the world.'},
#  {'title': 'Lavish Ambani wedding divides opinions in India',
#   'description': 'The noise around the lavish wedding has drawn public fascination - and ire.'},
#  {'title': 'Former PMs, film and sports stars join Ambani wedding',
#   'description': "Tony Blair and Boris Johnson were among guests to arrive at the wedding of a billionaire's son."},
#  {'title': 'WATCH: Families mourn victims of deadly India crush',
#   'description': 'At least 121 people, mostly women, were killed in the crush at a religious event in northern India.'},
#  {'title': 'Watch: Delhi airport roof collapses due to heavy rain',
#   'description': 'The incident has left one person dead and injured four others.'},
#  {'title': "What worked for India's Modi - and what didn’t?",
#   'description': "Indian Prime Minister Narendra Modi and his party have won the most seats in this year's election."},
#  {'title': 'Arrests, accusations and AI: India’s election unpacked',
#   'description': 'On 4 June, Indians will find out who governs their country for the next five years.'}]

# %%
for article in articles_formatted:
    category,max_sim = classify_article(article)
    print(f"Title: {article['title']}\nCategory: {category}\n")
# Out:
# Title: Modi's BJP ahead in Haryana election but trails in Kashmir
# Category: Terrorism / protest / political unrest / riot
#
# Title: Indian financial aid opens 'new chapter' with Maldives
# Category: Terrorism / protest / political unrest / riot
#
# Title: Why are there so many dropped catches at T20 World Cup?
# Category: Others
#
# Title: Climbers rescued after three days in the Himalayas
# Category: Others
#
# Title: Maldives president visits India amid trouble in tourist paradise
# Category: Terrorism / protest / political unrest / riot
#
# Title: The Polish artist who painted Hindu gods in Indian palaces
# Category: Terrorism / protest / political unrest / riot
#
# Title: India government says criminalising marital rape 'excessively harsh'
# Category: Terrorism / protest / political unrest / riot
#
# Title: India's foreign minister to visit Pakistan for the first time since 2015
# Category: Terrorism / protest / political unrest / riot
#
# Title: How India became a Test cricket powerhouse
# Category: Others
#
# Title: India's iconic tramcars set to ride into Kolkata sunset
# Category: Terrorism / protest / political unrest / riot
#
# Title: My mission is to take Tamil music global, says Sid Sriram
# Category: Terrorism / protest / political unrest / riot
#
# Title: India's top court saves a poor student's college dream
# Category: Terrorism / protest / political unrest / riot
#
# Title: The 'mastermind' behind India's biggest jailbreak
# Category: Terrorism / protest / political unrest / riot
#
# Title: The world’s diamond polishing capital feels Ukraine war impact
# Category: Terrorism / protest / political unrest / riot
#
# Title: Sold out in minutes, resold for millions: Coldplay tickets spark outrage in India
# Category: Terrorism / protest / political unrest / riot
#
# Title: A famed holy sweet in an unsavoury row in India
# Category: Terrorism / protest / political unrest / riot
#
# Title: Your essential guide to the ICC Women's T20 World Cup
# Category: Others
#
# Title: The Kashmiri politician whose return from jail ruffled feathers
# Category: Terrorism / protest / political unrest / riot
#
# Title: Death of Indian employee sparks debate on 'toxic work culture'
# Category: Terrorism / protest / political unrest / riot
#
# Title: Tigers and crocs make mangrove preservation tough work
# Category: Terrorism / protest / political unrest / riot
#
# Title: How Punjabi megastar Diljit Dosanjh is inspiring the next gen
# Category: Terrorism / protest / political unrest / riot
#
# Title: Hema committee report: Why are India's biggest film stars silent?
# Category: Terrorism / protest / political unrest / riot
#
# Title: Volunteers dying as Russia’s war dead tops 70,000
# Category: Terrorism / protest / political unrest / riot
#
# Title: Why hundreds of Samsung workers are protesting in India
# Category: Terrorism / protest / political unrest / riot
#
# Title: 'Please save me': The Indians duped into fighting for Russia
# Category: Terrorism / protest / political unrest / riot
#
# Title: After a decade, Kashmir votes in historic elections
# Category: Terrorism / protest / political unrest / riot
#
# Title: The German woman who helped build an Indian university
# Category: Terrorism / protest / political unrest / riot
#
# Title: Bangladesh leader’s ‘megaphone diplomacy’ irks India
# Category: Terrorism / protest / political unrest / riot
#
# Title: India's oldest trams may soon be brought to a halt
# Category: Terrorism / protest / political unrest / riot
#
# Title: Kolkata night protest: 'Today I witnessed history'
# Category: Terrorism / protest / political unrest / riot
#
# Title: Watch: Thousands of women protest about rape and murder of doctor in India
# Category: Terrorism / protest / political unrest / riot
#
# Title: Watch: Building collapses into river in Himachal Pradesh
# Category: Terrorism / protest / political unrest / riot
#
# Title: Watch: Blue screens, queues and airport delays worldwide
# Category: Terrorism / protest / political unrest / riot
#
# Title: Lavish Ambani wedding divides opinions in India
# Category: Terrorism / protest / political unrest / riot
#
# Title: Former PMs, film and sports stars join Ambani wedding
# Category: Terrorism / protest / political unrest / riot
#
# Title: WATCH: Families mourn victims of deadly India crush
# Category: Terrorism / protest / political unrest / riot
#
# Title: Watch: Delhi airport roof collapses due to heavy rain
# Category: Terrorism / protest / political unrest / riot
#
# Title: What worked for India's Modi - and what didn’t?
# Category: Terrorism / protest / political unrest / riot
#
# Title: Arrests, accusations and AI: India’s election unpacked
# Category: Terrorism / protest / political unrest / riot

# %%
import feedparser
from datetime import datetime

rss_feeds = [
    'http://rss.cnn.com/rss/cnn_topstories.rss',
    'http://qz.com/feed',
    'http://feeds.foxnews.com/foxnews/politics',
    'http://feeds.reuters.com/reuters/businessNews',
    'http://feeds.feedburner.com/NewshourWorld',
    'https://feeds.bbci.co.uk/news/world/asia/india/rss.xml'
]

def parse_feed(url):
    feed = feedparser.parse(url)
    articles = []
    for entry in feed.entries:
        # Extract the media content (if available)
        media_content = None
        if 'media_content' in entry:
            media_content = entry.media_content[0]['url'] if entry.media_content else None
        
        # Extract published date
        published_date = None
        if hasattr(entry, 'published_parsed'):
            published_date = datetime(*entry.published_parsed[:6])
        
        article = {
            'title': entry.title,
            'content': entry.summary if 'summary' in entry else '',  # Handle missing summary
            'published': published_date,
            'url': entry.link,
            'media_url': media_content , 
            'category':""
        }
        articles_required = {
            'title': entry.title,
            'description': entry.summary if 'summary' in entry else '',
        }
        article_category,sim = classify_article(articles_required)
        article['category'] = article_category
        articles.append(article)
    return articles

print(parse_feed('http://rss.cnn.com/rss/cnn_topstories.rss'))
# Out:
# [{'title': 'Some on-air claims about Dominion Voting Systems were false, Fox News acknowledges in statement after deal is announced', 'content': '', 'published': datetime.datetime(2023, 4, 19, 12, 44, 51), 'url': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418164538-02-dominion-fox-trial-settlement-0418-super-169.jpg', 'category': 'Terrorism / protest / political unrest / riot'}, {'title': 'Dominion still has pending lawsuits against election deniers such as Rudy Giuliani and Sidney Powell', 'content': '', 'published': None, 'url': 'https://www.cnn.com/business/live-news/fox-news-dominion-trial-04-18-23/h_8d51e3ae2714edaa0dace837305d03b8', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417170417-fox-news-headquarters-0228-super-169.jpg', 'category': 'Terrorism / protest / political unrest / riot'}, {'title': 'Here are the 20 specific Fox broadcasts and tweets Dominion says were defamatory', 'content': "• Fox-Dominion trial delay 'is not unusual,' judge says\n• Fox News' defamation battle isn't stopping Trump's election lies", 'published': datetime.datetime(2023, 4, 17, 16, 1, 11), 'url': 'https://www.cnn.com/2023/04/17/media/dominion-fox-news-allegations/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230416140110-maria-bartiromo-file-020823-restricted-super-169.jpg', 'category': 'Terrorism / protest / political unrest / riot'}, {'title': "Judge in Fox News-Dominion defamation trial: 'The parties have resolved their case'", 'content': 'The judge just announced in court that a settlement has been reached in the historic defamation case between Fox News and Dominion Voting Systems.', 'published': datetime.datetime(2023, 4, 19, 8, 28, 17), 'url': 'https://www.cnn.com/2023/04/18/media/fox-dominion-settlement/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418112020-02-delaware-fox-dominion-trial-court-exterior-0418-super-169.jpg', 'category': 'Terrorism / protest / political unrest / riot'}, {'title': "'Difficult to say with a straight face': Tapper reacts to Fox News' statement on settlement", 'content': "A settlement has been reached in Dominion Voting Systems' defamation case against Fox News, the judge for the case announced. The network will pay more than $787 million to Dominion, a lawyer for the company said.", 'published': datetime.datetime(2023, 4, 18, 21, 17, 44), 'url': 'https://www.cnn.com/videos/politics/2023/04/18/jake-tapper-dominion-lawsuit-settlement-fox-news-statement-lead-vpx.cnn', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230418164748-tapper-smile-vpx-super-169.jpg', 'category': 'Terrorism / protest / political unrest / riot'}, {'title': 'Millions in the US could face massive consequences unless McCarthy can navigate out of a debt trap he set for Biden', 'content': '• DeSantis goes to Washington, a place he once despised, looking for support to take on Trump\n• Opinion: For the GOP to win, it must ditch Trump\n• Chris Christie mulling 2024 White House bid\n• Analysis: The fire next time has begun burning in Tennessee', 'published': datetime.datetime(2023, 4, 18, 20, 34, 45), 'url': 'https://www.cnn.com/2023/04/18/politics/mccarthy-biden-debt-ceiling/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/assets/230417222359-mccarthy-biden-debt-ceiling-042023-super-169.jpg', 'category': 'Terrorism / protest / political unrest / riot'}, {'title': 'White homeowner accused of shooting a Black teen who rang his doorbell turns himself in to face criminal charges', 'content': "• 'A major part of Ralph died': Aunt of teen shot after ringing wrong doorbell speaks\n• 20-year-old woman shot after friend turned into the wrong driveway in upstate New York, officials say", 'published': datetime.datetime(2023, 4, 19, 4, 29, 5), 'url': 'https://www.cnn.com/2023/04/18/us/kansas-city-ralph-yarl-shooting-tuesday/index.html', 'media_url': 'https://cdn.cnn.com/cnnnext/dam/as ...
